# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

df = pd.read_csv ("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['math score'].mean()
# Out:
# 66.089

# %%
df['reading score'].median()
# Out:
# 70.0

# %%
df['writing score'].mode()
# Out:
# 0    74
# Name: writing score, dtype: int64

# %%
df['reading score'].hist()
# Out:
# <Axes: >

# %%
df.plot.scatter(x='gender', y = 'math score', color = 'green')
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 995    95
# 996    55
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 1000, dtype: int64>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#this is this data exploration of the Median of all of the test score 
median_math = np.median(df['math score'])
median_read = np.median(df['reading score'])
median_write = np.median(df['writing score'])
print("Median math score:", median_math )
print("Median reading score:", median_read )
print("Median writing score:", median_write)
# Out:
# Median math score: 66.0
# Median reading score: 70.0
# Median writing score: 69.0

# %%
#this is the data exploration of the Standard deviation of all the test score. 
sdMath = np.std(df['math score'])
sdRead = np.std(df['reading score'])
sdWrite = np.std(df['writing score'])
print (" The standard deviation of math is:",sdMath)
print (" The standard deviation of reading is:",sdRead)
print (" The standard deviation of writing is:",sdWrite)
# Out:
#  The standard deviation of math is: 15.155496659628165
#  The standard deviation of reading is: 14.59289001534652
#  The standard deviation of writing is: 15.188057281956759

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=df, x='gender')
plt.title('Distribution of Gender')
plt.show()

# %%
color = ['#f673a9', '#7ec8d4', '#ece5b4', '#9a4496']
plt.figure(figsize=(12, 8))

plt.subplot(3, 2, 1)
sns.countplot(data=df, x='gender', palette='husl')
plt.title('Distribution of Gender')

plt.subplot(3, 2, 2)
sns.countplot(data=df, x='race/ethnicity', palette = 'husl')
plt.title('Distribution of Race/Ethnicity')
plt.xticks(rotation=45)

# Plot Parental Level of Education
plt.subplot(3, 2, 3)
sns.countplot(data=df, x='parental level of education',palette = 'husl')
plt.title('Distribution of Parental Level of Education')
plt.xticks(rotation=45)

# Plot Lunch
plt.subplot(3, 2, 4)
sns.countplot(data=df, x='lunch',palette = 'husl')
plt.title('Distribution of Lunch')

# Plot Test Preparation Course
plt.subplot(3, 2, 5)
sns.countplot(data=df, x='test preparation course',palette = 'husl')
plt.title('Distribution of Test Preparation Course')

plt.tight_layout()
plt.show()

# %%
math_skewness = df['math score'].skew()
reading_skewness = df['reading score'].skew()
writing_skewness = df['writing score'].skew()
print('Skewness of Math Score:',math_skewness)
print('Skewness of Reading Score:',reading_skewness)
print('Skewness of Writing Score:',writing_skewness)
# Out:
# Skewness of Math Score: -0.27893514909431694
# Skewness of Reading Score: -0.25910451810923063
# Skewness of Writing Score: -0.28944397150761897

# %%
colors = ['#f673a9', '#7ec8d4', '#ece5b4', '#9a4496']
plt.figure(figsize=(18, 12))

# Reading Score by Gender
plt.subplot(2, 3, 1)
sns.histplot(df[df['gender'] == 'female']['reading score'], kde=True, palette='husl', label='Female', bins=10)
sns.histplot(df[df['gender'] == 'male']['reading score'], kde=True,palette='husl' , label='Male', bins=10)
plt.title(f'Reading Score by Gender\nSkewness: {reading_skewness:.2f}')
plt.xlabel('Reading Score')
plt.legend()

# Reading Score by Race/Ethnicity
plt.subplot(2, 3, 2)
for group in df['race/ethnicity'].unique():
    sns.histplot(df[df['race/ethnicity'] == group]['reading score'], kde=True,palette='husl', label=group, bins=10)
plt.title('Reading Score by Race/Ethnicity')
plt.xlabel('Reading Score')
plt.legend()

# Reading Score by Parental Level of Education
plt.subplot(2, 3, 3)
for level in df['parental level of education'].unique():
    sns.histplot(df[df['parental level of education'] == level]['reading score'], kde=True,palette='husl', label=level, bins=10)
plt.title('Reading Score by Parental Level of Education')
plt.xlabel('Reading Score')
plt.legend()
plt.xticks(rotation=45)

# Reading Score by Lunch
plt.subplot(2, 3, 4)
sns.histplot(df[df['lunch'] == 'standard']['reading score'], kde=True,palette='husl', label='Standard', bins=10)
sns.histplot(df[df['lunch'] == 'free/reduced']['reading score'], kde=True, palette='husl', label='Free/Reduced', bins=10)
plt.title('Reading Score by Lunch')
plt.xlabel('Reading Score')
plt.legend()

# Reading Score by Test Preparation Course
plt.subplot(2, 3, 5)
sns.histplot(df[df['test preparation course'] == 'none']['reading score'], kde=True,palette='husl', label='None', bins=10)
sns.histplot(df[df['test preparation course'] == 'completed']['reading score'], kde=True,palette='husl', label='Completed', bins=10)
plt.title('Reading Score by Test Preparation Course')
plt.xlabel('Reading Score')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/735288784.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[df['gender'] == 'female']['reading score'], kde=True, palette='husl', label='Female', bins=10)
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/735288784.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[df['gender'] == 'male']['reading score'], kde=True,palette='husl' , label='Male', bins=10)
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/735288784.py:15: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[df['race/ethnicity'] == group]['reading score'], kde=True,palette='husl', label=group, bins=10)
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/735288784.py:15: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
# ...

# %%
plt.figure(figsize=(18, 12))

# Math Score by Gender
plt.subplot(2, 3, 1)
sns.histplot(df[df['gender'] == 'female']['math score'], kde=True, palette='husl', label='Female', bins=10)
sns.histplot(df[df['gender'] == 'male']['math score'], kde=True, palette='husl',label='Male', bins=10)
plt.title(f'Math Score by Gender\nSkewness: {math_skewness:.2f}')
plt.xlabel('Math Score')
plt.legend()

# Math Score by Race/Ethnicity
plt.subplot(2, 3, 2)
for group in df['race/ethnicity'].unique():
    sns.histplot(df[df['race/ethnicity'] == group]['math score'], kde=True,palette='husl', label=group, bins=10)
plt.title('Math Score by Race/Ethnicity')
plt.xlabel('Math Score')
plt.legend()

# Math Score by Parental Level of Education
plt.subplot(2, 3, 3)
for level in df['parental level of education'].unique():
    sns.histplot(df[df['parental level of education'] == level]['math score'], kde=True, palette='husl',label=level, bins=10)
plt.title('Math Score by Parental Level of Education')
plt.xlabel('Math Score')
plt.legend()
plt.xticks(rotation=45)

#Math Score by Lunch
plt.subplot(2, 3, 4)
sns.histplot(df[df['lunch'] == 'standard']['math score'], kde=True,palette='husl',label='Standard', bins=10)
sns.histplot(df[df['lunch'] == 'free/reduced']['math score'], kde=True, palette='husl', label='Free/Reduced', bins=10)
plt.title('Math Score by Lunch')
plt.xlabel('Math Score')
plt.legend()

# Math Score by Test Preparation Course
plt.subplot(2, 3, 5)
sns.histplot(df[df['test preparation course'] == 'none']['math score'], kde=True, palette='husl', label='None', bins=10)
sns.histplot(df[df['test preparation course'] == 'completed']['math score'], kde=True, palette='husl',label='Completed', bins=10)
plt.title('Math Score by Test Preparation Course')
plt.xlabel('Math Score')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/3082381640.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[df['gender'] == 'female']['math score'], kde=True, palette='husl', label='Female', bins=10)
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/3082381640.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[df['gender'] == 'male']['math score'], kde=True, palette='husl',label='Male', bins=10)
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/3082381640.py:14: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[df['race/ethnicity'] == group]['math score'], kde=True,palette='husl', label=group, bins=10)
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/3082381640.py:14: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
# ...

# %%
colors = ['#f673a9', '#7ec8d4', '#ece5b4', '#9a4496']
plt.figure(figsize=(18, 12))

# Writing Score by Gender
plt.subplot(2, 3, 1)
sns.histplot(df[df['gender'] == 'female']['writing score'], kde=True, palette='husl', label='Female', bins=10)
sns.histplot(df[df['gender'] == 'male']['writing score'], kde=True, palette='husl', label='Male', bins=10)
plt.title(f'Writing Score by Gender\nSkewness: {reading_skewness:.2f}')
plt.xlabel('Writing Score')
plt.legend()

# Writing Score by Race/Ethnicity
plt.subplot(2, 3, 2)
for group in df['race/ethnicity'].unique():
    sns.histplot(df[df['race/ethnicity'] == group]['writing score'], kde=True, palette='husl',label=group, bins=10)
plt.title('Writing Score by Race/Ethnicity')
plt.xlabel('Writing Score')
plt.legend()

# Writing Score by Parental Level of Education
plt.subplot(2, 3, 3)
for level in df['parental level of education'].unique():
    sns.histplot(df[df['parental level of education'] == level]['writing score'], kde=True, palette='husl',label=level, bins=10)
plt.title('Writing Score by Parental Level of Education')
plt.xlabel('Writing Score')
plt.legend()
plt.xticks(rotation=45)

# writing Score by Lunch
plt.subplot(2, 3, 4)
sns.histplot(df[df['lunch'] == 'standard']['writing score'], kde=True,palette='husl', label='Standard', bins=10)
sns.histplot(df[df['lunch'] == 'free/reduced']['writing score'], kde=True, palette='husl', label='Free/Reduced', bins=10)
plt.title('Writing Score by Lunch')
plt.xlabel('Writing Score')
plt.legend()

# Reading Score by Test Preparation Course
plt.subplot(2, 3, 5)
sns.histplot(df[df['test preparation course'] == 'none']['writing score'], kde=True, palette='husl', label='None', bins=10)
sns.histplot(df[df['test preparation course'] == 'completed']['writing score'], kde=True, palette='husl',label='Completed', bins=10)
plt.title('Writing Score by Test Preparation Course')
plt.xlabel('Writing Score')
plt.legend()


plt.tight_layout()
plt.show()
# Out:
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/1564234935.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[df['gender'] == 'female']['writing score'], kde=True, palette='husl', label='Female', bins=10)
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/1564234935.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[df['gender'] == 'male']['writing score'], kde=True, palette='husl', label='Male', bins=10)
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/1564234935.py:15: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[df['race/ethnicity'] == group]['writing score'], kde=True, palette='husl',label=group, bins=10)
# /var/folders/1_/1rgvdcnx17v4crtn345q7mwm0000gn/T/ipykernel_46850/1564234935.py:15: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
# ...

# %%
colors = ['#f673a9', '#7ec8d4', '#ece5b4', '#9a4496']
bins = [0, 60, 70, 100]  # Low (0-59), Medium (60-69), High (70-100)


df['math_score_category'] = pd.cut(df['math score'], bins=bins, labels=['Low', 'Medium', 'High'])
df['reading_score_category'] = pd.cut(df['reading score'], bins=bins, labels=['Low', 'Medium', 'High'])
df['writing_score_category'] = pd.cut(df['writing score'], bins=bins, labels=['Low', 'Medium', 'High'])

plt.figure(figsize=(18, 6))

# Pie chart for the math stuff
plt.subplot(1, 3, 1)
math_counts = df['math_score_category'].value_counts()
plt.pie(math_counts, labels=math_counts.index, autopct='%1.1f%%', colors=colors)
plt.title('Math Score Distribution')

# Pie chart for the reading stuff
plt.subplot(1, 3, 2)
reading_counts = df['reading_score_category'].value_counts()
plt.pie(reading_counts, labels=reading_counts.index, autopct='%1.1f%%', colors=colors)
plt.title('Reading Score Distribution')

# Pie chart for writing stuff
plt.subplot(1, 3, 3)
writing_counts = df['writing_score_category'].value_counts()
plt.pie(writing_counts, labels=writing_counts.index, autopct='%1.1f%%', colors=colors)
plt.title('Writing Score Distribution')

plt.tight_layout()
plt.show()
# what i mena by high low and medium is to show what percentage scored high low and mediuam on all sections.
